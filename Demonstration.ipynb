# %% [markdown]
# ## Demonstration of General Market Analysis

# %%
import Code.MarketAnalysis as MA

# %%
MA.GeneralAnalysis()
# Out:
#        Trending  Ranging Standard Deviation Annual Volatility Overall Mean  \
# AUDUSD  40.42 %  59.58 %             0.61 %            9.74 %    -0.0040 %
# EURUSD  39.32 %  60.68 %             0.49 %            7.80 %    -0.0017 %
# GBPUSD  31.11 %  68.89 %             0.60 %            9.46 %    -0.0051 %
# USDCAD  39.70 %  60.30 %             0.48 %            7.61 %     0.0050 %
# USDCHF  32.51 %  67.49 %             0.56 %            8.96 %    -0.0035 %
# USDJPY  38.93 %  61.07 %             0.52 %            8.20 %    -0.0012 %
#
#        Positiv Mean Negativ Mean Positiv Bars Negativ Bars Total Bars
# AUDUSD       0.45 %      -0.48 %      51.10 %      48.84 %       1816
# EURUSD       0.36 %      -0.37 %      49.94 %      49.89 %       1816
# GBPUSD       0.43 %      -0.42 %      48.90 %      50.88 %       1816
# USDCAD       0.36 %      -0.37 %      51.21 %      48.68 %       1816
# USDCHF       0.34 %      -0.38 %      52.23 %      47.60 %       1816
# ...

# %% [markdown]
# ## Demonstration of Portfolio Functions

# %%
import Code.Portfolio as PF

# %%
PF.SingleAsset("EURUSD")
# Out:
#                         Actual Return Annualized Return  \
# EURUSD Major Daily 2021       -2.36 %     -10.91 % p.a.
#
#                         Maximum Relativ Drawdown Performance  \
# EURUSD Major Daily 2021                   4.97 %       -2.20
#
#                         Annualized Sortino Ratio Risk-Reward-Ratio  WinRate  \
# EURUSD Major Daily 2021                   -2.180              0.79  50.00 %
#
#                         LossRate Expectancy     Edge Number of Trades / Bars
# EURUSD Major Daily 2021  50.00 %  -0.0453 %  -5.86 %                      52

# %%
PF.Portfolio()
# Out:
#                  Actual Return Annualized Return Maximum Relativ Drawdown  \
# Major Daily 2021       -0.32 %      -1.56 % p.a.                   2.23 %
#
#                  Performance Alpha SP500 Beta SP500 Annualized Sortino Ratio  \
# Major Daily 2021       -0.70         nan        nan                   -0.527
#
#                  Risk-Reward-Ratio  WinRate LossRate Expectancy     Edge  \
# Major Daily 2021              0.81  53.85 %  46.15 %  -0.0062 %  -1.43 %
#
#                  Number of Trades / Bars
# Major Daily 2021                      52

# %%
PF.MultiPortfolio()
# Out:
#                  Actual Return Annualized Return Maximum Relativ Drawdown  \
# Major Daily 2021       -0.32 %      -1.56 % p.a.                   2.23 %
# Major Daily 2020       -3.14 %     -14.32 % p.a.                   3.81 %
# Major Daily 2019        0.77 %       3.80 % p.a.                   1.25 %
# Major Daily 2018        0.13 %       0.62 % p.a.                   1.65 %
# Major Daily 2017       -2.93 %     -13.42 % p.a.                   3.50 %
# Major Daily 2016       -0.75 %      -3.59 % p.a.                   1.67 %
# Major Daily 2015       -3.30 %     -15.00 % p.a.                   4.51 %
#
#                  Performance Alpha SP500 Beta SP500 Annualized Sortino Ratio  \
# Major Daily 2021       -0.70         nan        nan                   -0.527
# Major Daily 2020       -3.76      -14.53     -0.013                   -5.265
# Major Daily 2019        3.05         nan        nan                    1.805
# ...

# %%
PF.OptimizationPortfolio()
# Out:
#                              0.10 %    0.42 %    0.74 %    1.07 %    1.39 %  \
# Sortino Ratio TP AUDUSD    0.107100 -0.029227 -0.219126  0.737373  0.727870
# Sortino Ratio SL AUDUSD  -39.931084 -0.043423  0.123929 -0.158989 -0.142517
# Sortino Ratio TP EURUSD   -1.029902 -1.073549 -0.872175 -1.075960 -1.022278
# Sortino Ratio SL EURUSD  -19.455957 -3.628671 -2.574043 -1.818551 -1.562837
# Sortino Ratio TP GBPUSD   -0.876387 -1.878677 -2.195440 -2.088102 -2.036288
# Sortino Ratio SL GBPUSD  -13.367927 -4.024939 -3.467348 -2.654396 -2.590589
# Sortino Ratio TP USDCAD   -0.230099 -0.994091 -0.790654 -0.829307 -0.914802
# Sortino Ratio SL USDCAD   -2.169723 -1.361646 -1.196616 -1.191332 -1.119607
# Sortino Ratio TP USDCHF    0.627545 -1.173909 -0.880863 -1.042025 -0.810323
# Sortino Ratio SL USDCHF -554.338267 -2.809522 -1.877357 -1.146837 -1.134388
# Sortino Ratio TP USDJPY   -1.231674 -2.068410 -1.994495 -1.994809 -1.892862
# ...

# %% [markdown]
# ## Demonstration of SMA Strategie

# %%
import Code.SimpleStrategy as SS

# %%
SS.Portfolio()
# Out:
#     Actual Return Annualized Return Maximum Relativ Drawdown Performance  \
# SMA      -86.74 %     -16.33 % p.a.                  77.17 %       -0.21
#
#     Alpha SP500 Beta SP500 Annualized Sortino Ratio Risk-Reward-Ratio  \
# SMA       -3.37     -0.078                   -0.334              0.94
#
#      WinRate LossRate Expectancy     Edge Number of Trades / Bars
# SMA  49.89 %  49.37 %  -0.0304 %  -1.52 %                    2856
